# %% [markdown]
# You’re a programmer working for Copeland’s Corporate Company. At this company, each employee’s user name is generated by taking the first five letters of their last name.
#
# A new employee, Rodrigo Villanueva, is starting today and you need to create his account.

# %%
first_name = "Rodrigo"
last_name = "Villanueva"

# %%
new_account = last_name[:5]
new_account
# Out:
# 'Villa'

# %% [markdown]
# Temporary passwords for new employees are also generated from their last names.

# %%
temp_password = last_name[2:6]
temp_password
# Out:
# 'llan'

# %% [markdown]
# Copeland’s Corporate Company has realized that their policy of using the first five letters of an employee’s last name as a user name isn’t ideal when they have multiple employees with the same last name.

# %%
new_account = first_name[:3] + last_name[:3]

def account_generator(first_name, last_name):
    return new_account

# %%
account_generator("Rodrigo", "Villanueva")
# Out:
# 'RodVil'

# %% [markdown]
# Copeland’s Corporate Company also wants to update how they generate temporary passwords for new employees.

# %%
def password_generator(first_name, last_name):
    temp_password = first_name[len(first_name)-3:] + last_name[len(last_name)-3:]
    return temp_password

# %%
password_generator("Rodrigo", "Villanueva")
# Out:
# 'igoeva'

# %%
temp_password = password_generator(first_name, last_name)
temp_password
# Out:
# 'igoeva'

# %% [markdown]
# The most recent hire at Copeland’s Corporate Company is a fellow named Rob Daily. Unfortunately, Human Resources seem to have made a bit of a typo and sent over the wrong first_name. Try changing the first character.

# %%
first_name = "Bob"
last_name = "Daily"

fixed_first_name = "R" + first_name[1:]
print(fixed_first_name)
# Out:
# Rob

# %% [markdown]
# Copeland’s Corporate Company has finalized what they want their username and temporary password creation to be and have enlisted your help, once again, to build the function to generate them. In this exercise, you will create two functions, username_generator and password_generator.

# %%
def username_generator(first_name, last_name):
    username = first_name[:3] + last_name[:4]
    return username

# %%
username_generator("Zoe", "Lee")
# Out:
# 'ZoeLee'

# %%
username_generator("Abe", "Simpson")
# Out:
# 'AbeSimp'

# %%
def password_generator(username):
    for i in range(0, len(username)):
        password = username[-1] + username[:-1]
    return password

# %%
password_generator(username_generator("Abe", "Simpson"))
# Out:
# 'pAbeSim'

# %%
password_generator(username_generator("Zoe", "Lee"))
# Out:
# 'eZoeLe'

# %% [markdown]
# ---

# %%
favorite_fruit = 'blueberry'
counter = 0
for character in favorite_fruit:
    if character == 'b':
        counter += 1

# %%
counter
# Out:
# 2

# %%
def get_length(word):
    counter = 0
    for i in word:
        counter += 1
    return counter

# %%
get_length("blue")
# Out:
# 4

# %%
def letter_check(word, letter):
    for i in word:
        if i == letter:
            return True
    else:
        return False

# %%
letter_check("strawberry", "a")
# Out:
# True

# %%
"a" in "strawberry"
# Out:
# True

# %%
def contains(big_string, little_string):
    return little_string in big_string

# %%
contains('watermelon', 'melon')
# Out:
# True

# %%
contains('watermelon', 'berry')
# Out:
# False

# %%
def common_letters(string_one, string_two):
    common = []
    for letter in string_one:
        if (letter in string_two) and not (letter in common):
            common.append(letter)
    return common

# %%
common_letters("manhattan", "san fransisco")
# Out:
# ['a', 'n']
